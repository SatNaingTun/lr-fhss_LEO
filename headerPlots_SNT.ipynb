# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df_base = pd.read_csv("headerResults/snt/100_base.csv")
df_early = pd.read_csv("headerResults/snt/100_early.csv")

df_base.describe()
df_early.describe()

plt.figure()

plt.plot(df_base["sent_packets"],
         df_base["decoded_hrd_pld"],
         label="100 demod - base")

plt.plot(df_early["sent_packets"],
         df_early["decoded_hrd_pld"],
         label="100 demod - early Drop + early Decode")

plt.xscale("log")
plt.xlabel("Sent packets")
plt.ylabel("Total decoded payloads")
plt.legend()
plt.title("Total decoded payloads with 100 demodulators")
plt.show()

# %%
df_base = pd.read_csv("headerResults/snt/1000_base.csv")
df_early = pd.read_csv("headerResults/snt/1000_early.csv")

plt.figure()

plt.plot(df_base["sent_packets"],
         df_base["decoded_hrd_pld"],
         label="1000 demod - base")

plt.plot(df_early["sent_packets"],
         df_early["decoded_hrd_pld"],
         label="1000 demod - early Drop + early Decode")

plt.xscale("log")
plt.xlabel("Sent packets")
plt.ylabel("Total decoded payloads")
plt.legend()
plt.title("Total decoded payloads with 1000 demodulators")
plt.show()

# %%
df_base = pd.read_csv("headerResults/snt/inf_base.csv")
df_early = pd.read_csv("headerResults/snt/inf_early.csv")

plt.figure()

plt.plot(df_base["sent_packets"],
         df_base["decoded_hrd_pld"],
         label="Infinite demod - base")

plt.plot(df_early["sent_packets"],
         df_early["decoded_hrd_pld"],
         label="Infinite demod - early Drop + early Decode")

plt.xscale("log")
plt.xlabel("Sent packets")
plt.ylabel("Total decoded payloads")
plt.legend()
plt.title("Total decoded payloads with infinite demodulators")
plt.show()
